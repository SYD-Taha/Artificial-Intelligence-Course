# %%
import pandas as pd


s = pd.Series(['t','a','h','a'])

df = pd.DataFrame({'a':[1,2],'b':[3,4]})

print(s)
print(df)

a = pd.read_csv('/content/sample_data/california_housing_test.csv')
dff = pd.DataFrame(a)
dff.head()
# Out:
# 0    t
# 1    a
# 2    h
# 3    a
# dtype: object
#    a  b
# 0  1  3
# 1  2  4
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
dff.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
print(dff.columns)
print(dff.index)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# RangeIndex(start=0, stop=3000, step=1)

# %%
mean = dff['total_rooms'].mean()
print(mean)

dff[dff['total_rooms'] > mean]
# Out:
# 2599.578666666667
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
# ...

# %%
dff.iloc[0]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
dff.set_index('population')
# Out:
#             longitude  latitude  housing_median_age  total_rooms  \
# population
# 1537.0        -122.05     37.37                27.0       3885.0
# 809.0         -118.30     34.26                43.0       1510.0
# 1484.0        -117.81     33.78                27.0       3589.0
# 49.0          -118.36     33.82                28.0         67.0
# 850.0         -119.67     36.33                19.0       1241.0
# ...               ...       ...                 ...          ...
# 1258.0        -119.86     34.42                23.0       1450.0
# 3496.0        -118.14     34.06                27.0       5257.0
# 693.0         -119.70     36.30                10.0        956.0
# 46.0          -117.12     34.10                40.0         96.0
# 753.0         -119.63     34.42                42.0       1765.0
#
#             total_bedrooms  households  median_income  median_house_value
# population
# 1537.0               661.0       606.0         6.6085            344700.0
# ...

# %%
var = dff.loc[1537,'latitude']
print(var)
# Out:
# 38.92

# %%
dff['households'].unique()
# Out:
# array([ 606.,  277.,  495., ...,   92.,  607., 1036.])

# %%
dff['total_bedrooms'].value_counts()
# Out:
# total_bedrooms
# 314.0     15
# 270.0     12
# 299.0     11
# 459.0     10
# 493.0     10
#           ..
# 1599.0     1
# 599.0      1
# 1041.0     1
# 739.0      1
# 916.0      1
# Name: count, Length: 1055, dtype: int64

# %%
df['a'] = df['a'].apply(lambda x : x*2)
df['a']
# Out:
# 0     64
# 1    128
# Name: a, dtype: int64

# %%
dff[dff['latitude'] > 39]
# Out:
#              longitude  latitude  housing_median_age  total_bedrooms  \
# total_rooms
# 3442.0         -121.13     39.31                17.0           705.0
# 1581.0         -121.67     40.87                31.0           299.0
# 1421.0         -123.79     39.50                24.0           291.0
# 1564.0         -123.52     41.01                17.0           345.0
# 2141.0         -124.16     40.77                35.0           438.0
# ...                ...       ...                 ...             ...
# 1148.0         -124.14     40.60                27.0           206.0
# 3099.0         -122.08     40.64                14.0           519.0
# 2801.0         -122.33     40.52                23.0           507.0
# 2978.0         -124.09     40.55                24.0           553.0
# 2722.0         -122.64     41.63                19.0           479.0
#
#              population  households  median_income  median_house_value
# total_rooms
# ...

# %%
import numpy as np

new_df = pd.DataFrame({
    'math': [90, 0, 75],
    'science': [0, 88, 0]
})

# Replace all 0s with NaN
new_df = new_df.replace(0, np.nan)

print(new_df)
# Out:
#    math  science
# 0  90.0      NaN
# 1   NaN     88.0
# 2  75.0      NaN

# %%
import pandas as pd
import numpy as np


new_dataframe = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie','Taha','Ali'],
    'age': [25, 30, 35,0,0],
    'score': [250,303,53,0,0]

})

new_dataframe.replace(0,np.nan)
# Out:
#       name   age  score
# 0    Alice  25.0  250.0
# 1      Bob  30.0  303.0
# 2  Charlie  35.0   53.0
# 3     Taha   NaN    NaN
# 4      Ali   NaN    NaN

# %%
import pandas as pd
import numpy as np


new_dataframe = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie','Taha','Ali'],
    'age': [25, 30, 35,0,0],
    'score': [250,303,53,0,0]

})

new_dataframe.replace(0,np.nan, inplace=True)
mean_score = new_dataframe['score'].mean()
mean_age = new_dataframe['age'].mean()
values = {'age':mean_age,'score':mean_score}
print(values)
new_dataframe.fillna(value=values, inplace=True)
new_dataframe
# Out:
# {'age': np.float64(30.0), 'score': np.float64(202.0)}
#       name   age  score
# 0    Alice  25.0  250.0
# 1      Bob  30.0  303.0
# 2  Charlie  35.0   53.0
# 3     Taha  30.0  202.0
# 4      Ali  30.0  202.0

# %%
new_dataframe = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie','Taha','Ali'],
    'age': [25, 30, 35,0,0],
    'score': [250,303,53,0,0]

})

new_dataframe.replace(0,np.nan, inplace=True)

new_dataframe.dropna(  )
# Out:
#       name   age  score
# 0    Alice  25.0  250.0
# 1      Bob  30.0  303.0
# 2  Charlie  35.0   53.0

# %%
new_dataframe = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie','Taha','Ali'],
    'age': [25, 30, 35,0,0],
    'score': [250,303,53,0,0]

})
new_dataframe.replace(0,np.nan, inplace=True)

new_dataframe.interpolate( )
# Out:
# <ipython-input-39-da2a1eae3be6>:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_dataframe.interpolate( )
#       name   age  score
# 0    Alice  25.0  250.0
# 1      Bob  30.0  303.0
# 2  Charlie  35.0   53.0
# 3     Taha  35.0   53.0
# 4      Ali  35.0   53.0
